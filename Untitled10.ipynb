# %%
import pandas as pd
import pickle
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the data from the pickled file
file_path = '/content/drive/My Drive/synthetic_dataset/goal_set.p'
with open(file_path, 'rb') as file:
    consultation_data = pickle.load(file)

# Extract 'train' data
train_data = consultation_data['train']

# Lists to hold disease tags and symptoms
disease_tags = []
symptoms = []

# Extract disease tag and symptoms from each consultation in the 'train' data
for item in train_data:
    # Extract disease tag
    disease_tags.append(item['disease_tag'])

    # Extract symptoms
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms
    symptoms.append(all_symptoms)

# Create a DataFrame
df = pd.DataFrame({
    'Disease Tag': disease_tags,
    'Symptoms': symptoms
})

# Display the DataFrame
print(df)
# Out:
# Mounted at /content/drive
#                                     Disease Tag  \
# 0      Central retinal artery or vein occlusion
# 1                     Degenerative disc disease
# 2                          Diabetic retinopathy
# 3                             Chronic back pain
# 4                                  Air embolism
# ...                                         ...
# 23995                                Concussion
# 23996                          Cushing syndrome
# 23997                              Fibromyalgia
# 23998                              Dengue fever
# 23999                                 Flat feet
#
#                                                 Symptoms
# 0      [Spots or clouds in vision, Diminished vision,...
# 1      [Shoulder pain, Back pain, Low back pain, Neck...
# 2                        [Foreign body sensation in eye]
# 3                  [Low back pain, Back pain, Side pain]
# 4      [Wrist pain, Pain in eye, Shoulder cramps or s...
# ...                                                  ...
# 23995                      [Neck pain, Headache, Nausea]
# 23996                                      [Weight gain]
# 23997  [Low back pain, Back pain, Ache all over, Shou...
# 23998  [Fever, Sore throat, Wrist pain, Pain during p...
# 23999          [Knee pain, Foot or toe pain, Ankle pain]
#
# [24000 rows x 2 columns]

# %%
df
# Out:
#                                     Disease Tag  \
# 0      Central retinal artery or vein occlusion
# 1                     Degenerative disc disease
# 2                          Diabetic retinopathy
# 3                             Chronic back pain
# 4                                  Air embolism
# ...                                         ...
# 23995                                Concussion
# 23996                          Cushing syndrome
# 23997                              Fibromyalgia
# 23998                              Dengue fever
# 23999                                 Flat feet
#
#                                                 Symptoms
# 0      [Spots or clouds in vision, Diminished vision,...
# 1      [Shoulder pain, Back pain, Low back pain, Neck...
# 2                        [Foreign body sensation in eye]
# 3                  [Low back pain, Back pain, Side pain]
# 4      [Wrist pain, Pain in eye, Shoulder cramps or s...
# ...                                                  ...
# 23995                      [Neck pain, Headache, Nausea]
# 23996                                      [Weight gain]
# 23997  [Low back pain, Back pain, Ache all over, Shou...
# 23998  [Fever, Sore throat, Wrist pain, Pain during p...
# 23999          [Knee pain, Foot or toe pain, Ankle pain]
#
# [24000 rows x 2 columns]

# %%
# Dictionary to hold symptoms and the diseases they appear in
symptom_disease_map = {}

# Iterate through each consultation in the 'train' data
for item in train_data:
    disease_tag = item['disease_tag']
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms

    # Update the symptom-disease mapping
    for symptom in all_symptoms:
        if symptom not in symptom_disease_map:
            symptom_disease_map[symptom] = set()
        symptom_disease_map[symptom].add(disease_tag)

# List to hold repeating symptoms
repeating_symptoms = []

# Iterate through the symptom-disease mapping to find repeating symptoms
for symptom, diseases in symptom_disease_map.items():
    if len(diseases) > 1:
        repeating_symptoms.append((symptom, len(diseases)))

# Print the repeating symptoms along with the number of diseases they appear in
print("Repeating Symptoms and Number of Diseases:")
for idx, (symptom, num_diseases) in enumerate(repeating_symptoms, start=1):
    print(f"{idx}. {symptom}: {num_diseases} diseases")
# Out:
# Repeating Symptoms and Number of Diseases:
# 1. Spots or clouds in vision: 7 diseases
# 2. Diminished vision: 12 diseases
# 3. Symptoms of eye: 11 diseases
# 4. Pain in eye: 18 diseases
# 5. Shoulder pain: 7 diseases
# 6. Back pain: 13 diseases
# 7. Low back pain: 6 diseases
# 8. Neck pain: 9 diseases
# 9. Hip pain: 7 diseases
# 10. Ache all over: 11 diseases
# 11. Foreign body sensation in eye: 7 diseases
# 12. Side pain: 6 diseases
# 13. Wrist pain: 10 diseases
# 14. Shoulder cramps or spasms: 6 diseases
# 15. Facial pain: 8 diseases
# 16. Ankle pain: 9 diseases
# 17. Pain during pregnancy: 6 diseases
# 18. Joint stiffness or tightness: 7 diseases
# 19. Pain or soreness of breast: 8 diseases
# 20. Knee lump or mass: 9 diseases
# 21. Excessive urination at night: 5 diseases
# 22. Skin rash: 15 diseases
# 23. Skin dryness, peeling, scaliness, or roughness: 6 diseases
# 24. Diarrhea: 3 diseases
# 25. Excessive anger: 10 diseases
# 26. Fatigue: 14 diseases
# 27. Depression: 10 diseases
# 28. Sweating: 2 diseases
# 29. Abnormal involuntary movements: 10 diseases
# 30. Cough: 9 diseases
# 31. Shortness of breath: 8 diseases
# 32. Diminished hearing: 2 diseases
# 33. Dizziness: 13 diseases
# 34. Anxiety and nervousness: 9 diseases
# 35. Abusing alcohol: 3 diseases
# 36. Sharp abdominal pain: 11 diseases
# 37. Eye redness: 10 diseases
# 38. Lacrimation: 8 diseases
# 39. Swollen eye: 9 diseases
# 40. Allergic reaction: 8 diseases
# 41. Nausea: 10 diseases
# 42. Hot flashes: 2 diseases
# 43. Vaginal pain: 4 diseases
# 44. Sharp chest pain: 10 diseases
# 45. Restlessness: 3 diseases
# 46. White discharge from eye: 3 diseases
# 47. Disturbance of memory: 7 diseases
# 48. Loss of sensation: 11 diseases
# 49. Seizures: 4 diseases
# 50. Arm stiffness or tightness: 2 diseases
# 51. Cramps and spasms: 4 diseases
# 52. Skin growth: 8 diseases
# 53. Abnormal appearing skin: 10 diseases
# 54. Skin lesion: 13 diseases
# 55. Skin swelling: 10 diseases
# 56. Itching of skin: 12 diseases
# 57. Depressive or psychotic symptoms: 12 diseases
# 58. Insomnia: 5 diseases
# 59. Leg pain: 14 diseases
# 60. Knee pain: 7 diseases
# 61. Problems with movement: 14 diseases
# 62. Mass on eyelid: 4 diseases
# 63. Eyelid swelling: 2 diseases
# 64. Eyelid lesion or rash: 5 diseases
# 65. Itchiness of eye: 11 diseases
# 66. Blindness: 3 diseases
# 67. Heavy menstrual flow: 2 diseases
# 68. Swelling of scrotum: 2 diseases
# 69. Hand or finger pain: 6 diseases
# 70. Retention of urine: 5 diseases
# 71. Weakness: 7 diseases
# 72. Headache: 13 diseases
# 73. Vomiting: 10 diseases
# 74. Double vision: 5 diseases
# 75. Lip swelling: 3 diseases
# 76. Foot or toe pain: 7 diseases
# 77. Weight gain: 5 diseases
# 78. Warts: 4 diseases
# 79. Pain in testicles: 3 diseases
# 80. Groin pain: 5 diseases
# 81. Painful urination: 5 diseases
# 82. Fever: 8 diseases
# 83. Elbow pain: 5 diseases
# 84. Bones are painful: 3 diseases
# 85. Intermenstrual bleeding: 4 diseases
# 86. Vaginal bleeding after menopause: 2 diseases
# 87. Leg cramps or spasms: 3 diseases
# 88. Pelvic pain: 6 diseases
# 89. Unpredictable menstruation: 3 diseases
# 90. Involuntary urination: 5 diseases
# 91. Vaginal discharge: 4 diseases
# 92. Fainting: 3 diseases
# 93. Difficulty in swallowing: 4 diseases
# 94. Penile discharge: 2 diseases
# 95. Wrist swelling: 4 diseases
# 96. Foot or toe swelling: 3 diseases
# 97. Delusions or hallucinations: 7 diseases
# 98. Difficulty speaking: 8 diseases
# 99. Lower abdominal pain: 4 diseases
# 100. Blood in urine: 4 diseases
# 101. Leg weakness: 4 diseases
# 102. Irritable infant: 2 diseases
# 103. Hostile behavior: 3 diseases
# 104. Hand or finger weakness: 2 diseases
# 105. Skin moles: 5 diseases
# 106. Bleeding or discharge from nipple: 2 diseases
# 107. Excessive appetite: 2 diseases
# 108. Frequent urination: 6 diseases
# 109. Paresthesia: 11 diseases
# 110. Excessive growth: 5 diseases
# 111. Vulvar sore: 2 diseases
# 112. Itchy eyelid: 4 diseases
# 113. Painful sinuses: 2 diseases
# 114. Symptoms of the kidneys: 3 diseases
# 115. Vaginal itching: 3 diseases
# 116. Feeling hot and cold: 3 diseases
# 117. Decreased appetite: 3 diseases
# 118. Hand or finger swelling: 4 diseases
# 119. Muscle pain: 4 diseases
# 120. Nasal congestion: 2 diseases
# 121. Knee swelling: 3 diseases
# 122. Arm pain: 9 diseases
# 123. Infertility: 3 diseases
# 124. Irregular appearing scalp: 5 diseases
# 125. Acne or pimples: 7 diseases
# 126. Fluid retention: 5 diseases
# 127. Peripheral edema: 6 diseases
# 128. Focal weakness: 3 diseases
# 129. Burning abdominal pain: 2 diseases
# 130. Irregular heartbeat: 3 diseases
# 131. Neck cramps or spasms: 2 diseases
# 132. Low self-esteem: 3 diseases
# 133. Feeling ill: 2 diseases
# 134. Abnormal movement of eyelid: 3 diseases
# 135. Suprapubic pain: 2 diseases
# 136. Loss of sex drive: 4 diseases
# 137. Elbow weakness: 5 diseases
# 138. Skin pain: 2 diseases
# 139. Sore throat: 2 diseases
# 140. Long menstrual periods: 4 diseases
# 141. Infrequent menstruation: 2 diseases
# 142. Unwanted hair: 2 diseases
# 143. Hemoptysis: 2 diseases
# 144. Skin on leg or foot looks infected: 3 diseases
# 145. Lymphedema: 2 diseases
# 146. Joint pain: 6 diseases
# 147. Rib pain: 3 diseases
# 148. Lower body pain: 6 diseases
# 149. Nailbiting: 6 diseases
# 150. Sleepiness: 2 diseases
# 151. Eye burns or stings: 5 diseases
# 152. Symptoms of the face: 2 diseases
# 153. Stiffness all over: 2 diseases
# 154. Elbow cramps or spasms: 6 diseases
# 155. Penis pain: 2 diseases
# 156. Lack of growth: 2 diseases
# 157. Fears and phobias: 5 diseases
# 158. Penis redness: 2 diseases
# 159. Palpitations: 2 diseases
# 160. Absence of menstruation: 4 diseases
# 161. Back weakness: 2 diseases
# 162. Eye strain: 2 diseases
# 163. Skin irritation: 5 diseases
# 164. Leg swelling: 3 diseases
# 165. Emotional symptoms: 5 diseases
# 166. Shoulder swelling: 3 diseases
# 167. Foot or toe stiffness or tightness: 2 diseases
# 168. Wrist weakness: 7 diseases
# 169. Pain during intercourse: 2 diseases
# 170. Nightmares: 2 diseases
# 171. Low back weakness: 5 diseases
# 172. Hoarse voice: 2 diseases
# 173. Muscle swelling: 4 diseases
# 174. Muscle cramps, contractures, or spasms: 2 diseases

# %%
# Dictionary to hold the number of symptoms for each disease
disease_symptom_count = {}

# Iterate through each consultation in the 'train' data
for item in train_data:
    disease_tag = item['disease_tag']
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms

    # Update the symptom count for the disease
    if disease_tag not in disease_symptom_count:
        disease_symptom_count[disease_tag] = len(set(all_symptoms))
    else:
        disease_symptom_count[disease_tag] += len(set(all_symptoms))

# Print the number of symptoms for each disease
print("Number of Symptoms for Each Disease:")
for disease, symptom_count in disease_symptom_count.items():
    print(f"{disease}: {symptom_count}")
# Out:
# Number of Symptoms for Each Disease:
# Central retinal artery or vein occlusion: 763
# Degenerative disc disease: 1181
# Diabetic retinopathy: 667
# Chronic back pain: 753
# Air embolism: 2594
# Dyshidrosis: 989
# Diaper rash: 676
# Conversion disorder: 1230
# Anxiety: 944
# Conductive hearing loss: 909
# Alcohol intoxication: 1204
# Conjunctivitis due to allergy: 1307
# Drug reaction: 1087
# Endometriosis: 877
# Granuloma inguinale: 981
# Extrapyramidal effect of drugs: 968
# Corneal disorder: 937
# Encephalitis: 1054
# Eczema: 958
# Actinic keratosis: 894
# Endometrial cancer: 529
# Adjustment reaction: 743
# Drug abuse cocaine: 805
# Chondromalacia of the patella: 553
# Chalazion: 959
# Alzheimer disease: 565
# Acariasis: 985
# Epidural hemorrhage: 956
# Guillain Barre syndrome: 1291
# Acute kidney injury: 840
# Cerebral edema: 1227
# Diabetic peripheral neuropathy: 668
# Cushing syndrome: 379
# Contact dermatitis: 699
# Epididymitis: 946
# Chickenpox: 1032
# Flat feet: 922
# Dissociative disorder: 895
# Decubitus ulcer: 311
# Amyotrophic lateral sclerosis ALS: 1147
# Endometrial hyperplasia: 559
# Carbon monoxide poisoning: 1191
# Chagas disease: 1037
# Carpal tunnel syndrome: 968
# Diabetes insipidus: 862
# Chronic pain disorder: 1101
# Fracture of the pelvis: 988
# Concussion: 951
# Gonorrhea: 988
# Gout: 938
# Chancroid: 1097
# Amyloidosis: 1101
# Cystitis: 1224
# Complex regional pain syndrome: 1111
# Essential tremor: 749
# Gas gangrene: 1188
# Cat scratch disease: 1751
# Fibrocystic breast disease: 475
# Factitious disorder: 1088
# Adhesive capsulitis of the shoulder: 819
# Carcinoid syndrome: 538
# Ectropion: 1382
# Endophthalmitis: 1239
# Chlamydia: 955
# Eating disorder: 842
# Fluid overload: 1180
# Fibromyalgia: 1234
# De Quervain disease: 935
# Fracture of the rib: 1034
# Ganglion cyst: 987
# Dermatitis due to sun exposure: 953
# Female infertility of unknown cause: 388
# Chronic kidney disease: 344
# Cystic Fibrosis: 432
# Acne: 624
# Corneal abrasion: 934
# Diabetic ketoacidosis: 1028
# Allergy: 959
# Erectile dysfunction: 627
# Cyst of the eyelid: 1035
# Erythema multiforme: 1263
# Dengue fever: 1476
# Acute glaucoma: 731
# Ankylosing spondylitis: 957
# Graves disease: 431
# Acanthosis nigricans: 647
# Acute stress reaction: 1044
# Aphakia: 619
# Connective tissue disorder: 1140
# Fat embolism: 3021

# %%
import pandas as pd

# Convert the dictionary to a DataFrame
df_symptom_count = pd.DataFrame.from_dict(disease_symptom_count, orient='index', columns=['Number of Symptoms'])

# Sort the DataFrame by the number of symptoms in descending order
df_symptom_count = df_symptom_count.sort_values(by='Number of Symptoms', ascending=False)

# Display the DataFrame
print("Number of Symptoms for Each Disease:")
print(df_symptom_count)
# Out:
# Number of Symptoms for Each Disease:
#                                      Number of Symptoms
# Fat embolism                                       3021
# Air embolism                                       2594
# Cat scratch disease                                1751
# Dengue fever                                       1476
# Ectropion                                          1382
# ...                                                 ...
# Graves disease                                      431
# Female infertility of unknown cause                 388
# Cushing syndrome                                    379
# Chronic kidney disease                              344
# Decubitus ulcer                                     311
#
# [90 rows x 1 columns]

# %%
# Dictionary to hold the number of symptoms (both explicit and implicit) for each disease
disease_total_symptom_count = {}

# Iterate through each consultation in the 'train' data
for item in train_data:
    disease_tag = item['disease_tag']
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms

    # Update the symptom count for the disease
    if disease_tag not in disease_total_symptom_count:
        disease_total_symptom_count[disease_tag] = len(set(all_symptoms))
    else:
        disease_total_symptom_count[disease_tag] += len(set(all_symptoms))

# Convert the dictionary to a DataFrame
df_total_symptom_count = pd.DataFrame.from_dict(disease_total_symptom_count, orient='index', columns=['Total Number of Symptoms'])

# Sort the DataFrame by the total number of symptoms in descending order
df_total_symptom_count = df_total_symptom_count.sort_values(by='Total Number of Symptoms', ascending=False)

# Display the DataFrame
print("Total Number of Symptoms (Explicit + Implicit) for Each Disease:")
print(df_total_symptom_count)
# Out:
# Total Number of Symptoms (Explicit + Implicit) for Each Disease:
#                                      Total Number of Symptoms
# Fat embolism                                             3021
# Air embolism                                             2594
# Cat scratch disease                                      1751
# Dengue fever                                             1476
# Ectropion                                                1382
# ...                                                       ...
# Graves disease                                            431
# Female infertility of unknown cause                       388
# Cushing syndrome                                          379
# Chronic kidney disease                                    344
# Decubitus ulcer                                           311
#
# [90 rows x 1 columns]

# %%
# Calculate the total number of diseases
total_diseases = len(associated_diseases)

# Assign probabilities to each repeating symptom based on the number of diseases they appear in
repeating_symptoms_with_prob = [(symptom, num_diseases, (num_diseases / total_diseases) * 100)
                                for symptom, num_diseases in repeating_symptoms]

# Sort the repeating symptoms based on their probabilities in descending order
repeating_symptoms_with_prob.sort(key=lambda x: x[2], reverse=True)

# Initialize a dictionary to hold the probability of each symptom
symptom_prob = {}

# Print the repeating symptoms along with their probabilities
print("Repeating Symptoms, Number of Diseases, and Probability (Sorted by Probability):")
for idx, (symptom, num_diseases, probability) in enumerate(repeating_symptoms_with_prob, start=1):
    symptom_prob[symptom] = probability  # Save the probability of the symptom
    print(f"{idx}. {symptom}: {num_diseases} diseases, Probability: {probability:.2f}%")
# Out:
# Repeating Symptoms, Number of Diseases, and Probability (Sorted by Probability):
# 1. Pain in eye: 18 diseases, Probability: 900.00%
# 2. Skin rash: 15 diseases, Probability: 750.00%
# 3. Fatigue: 14 diseases, Probability: 700.00%
# 4. Leg pain: 14 diseases, Probability: 700.00%
# 5. Problems with movement: 14 diseases, Probability: 700.00%
# 6. Back pain: 13 diseases, Probability: 650.00%
# 7. Dizziness: 13 diseases, Probability: 650.00%
# 8. Skin lesion: 13 diseases, Probability: 650.00%
# 9. Headache: 13 diseases, Probability: 650.00%
# 10. Diminished vision: 12 diseases, Probability: 600.00%
# 11. Itching of skin: 12 diseases, Probability: 600.00%
# 12. Depressive or psychotic symptoms: 12 diseases, Probability: 600.00%
# 13. Symptoms of eye: 11 diseases, Probability: 550.00%
# 14. Ache all over: 11 diseases, Probability: 550.00%
# 15. Sharp abdominal pain: 11 diseases, Probability: 550.00%
# 16. Loss of sensation: 11 diseases, Probability: 550.00%
# 17. Itchiness of eye: 11 diseases, Probability: 550.00%
# 18. Paresthesia: 11 diseases, Probability: 550.00%
# 19. Wrist pain: 10 diseases, Probability: 500.00%
# 20. Excessive anger: 10 diseases, Probability: 500.00%
# 21. Depression: 10 diseases, Probability: 500.00%
# 22. Abnormal involuntary movements: 10 diseases, Probability: 500.00%
# 23. Eye redness: 10 diseases, Probability: 500.00%
# 24. Nausea: 10 diseases, Probability: 500.00%
# 25. Sharp chest pain: 10 diseases, Probability: 500.00%
# 26. Abnormal appearing skin: 10 diseases, Probability: 500.00%
# 27. Skin swelling: 10 diseases, Probability: 500.00%
# 28. Vomiting: 10 diseases, Probability: 500.00%
# 29. Neck pain: 9 diseases, Probability: 450.00%
# 30. Ankle pain: 9 diseases, Probability: 450.00%
# 31. Knee lump or mass: 9 diseases, Probability: 450.00%
# 32. Cough: 9 diseases, Probability: 450.00%
# 33. Anxiety and nervousness: 9 diseases, Probability: 450.00%
# 34. Swollen eye: 9 diseases, Probability: 450.00%
# 35. Arm pain: 9 diseases, Probability: 450.00%
# 36. Facial pain: 8 diseases, Probability: 400.00%
# 37. Pain or soreness of breast: 8 diseases, Probability: 400.00%
# 38. Shortness of breath: 8 diseases, Probability: 400.00%
# 39. Lacrimation: 8 diseases, Probability: 400.00%
# 40. Allergic reaction: 8 diseases, Probability: 400.00%
# 41. Skin growth: 8 diseases, Probability: 400.00%
# 42. Fever: 8 diseases, Probability: 400.00%
# 43. Difficulty speaking: 8 diseases, Probability: 400.00%
# 44. Spots or clouds in vision: 7 diseases, Probability: 350.00%
# 45. Shoulder pain: 7 diseases, Probability: 350.00%
# 46. Hip pain: 7 diseases, Probability: 350.00%
# 47. Foreign body sensation in eye: 7 diseases, Probability: 350.00%
# 48. Joint stiffness or tightness: 7 diseases, Probability: 350.00%
# 49. Disturbance of memory: 7 diseases, Probability: 350.00%
# 50. Knee pain: 7 diseases, Probability: 350.00%
# 51. Weakness: 7 diseases, Probability: 350.00%
# 52. Foot or toe pain: 7 diseases, Probability: 350.00%
# 53. Delusions or hallucinations: 7 diseases, Probability: 350.00%
# 54. Acne or pimples: 7 diseases, Probability: 350.00%
# 55. Wrist weakness: 7 diseases, Probability: 350.00%
# 56. Low back pain: 6 diseases, Probability: 300.00%
# 57. Side pain: 6 diseases, Probability: 300.00%
# 58. Shoulder cramps or spasms: 6 diseases, Probability: 300.00%
# 59. Pain during pregnancy: 6 diseases, Probability: 300.00%
# 60. Skin dryness, peeling, scaliness, or roughness: 6 diseases, Probability: 300.00%
# 61. Hand or finger pain: 6 diseases, Probability: 300.00%
# 62. Pelvic pain: 6 diseases, Probability: 300.00%
# 63. Frequent urination: 6 diseases, Probability: 300.00%
# 64. Peripheral edema: 6 diseases, Probability: 300.00%
# 65. Joint pain: 6 diseases, Probability: 300.00%
# 66. Lower body pain: 6 diseases, Probability: 300.00%
# 67. Nailbiting: 6 diseases, Probability: 300.00%
# 68. Elbow cramps or spasms: 6 diseases, Probability: 300.00%
# 69. Excessive urination at night: 5 diseases, Probability: 250.00%
# 70. Insomnia: 5 diseases, Probability: 250.00%
# 71. Eyelid lesion or rash: 5 diseases, Probability: 250.00%
# 72. Retention of urine: 5 diseases, Probability: 250.00%
# 73. Double vision: 5 diseases, Probability: 250.00%
# 74. Weight gain: 5 diseases, Probability: 250.00%
# 75. Groin pain: 5 diseases, Probability: 250.00%
# 76. Painful urination: 5 diseases, Probability: 250.00%
# 77. Elbow pain: 5 diseases, Probability: 250.00%
# 78. Involuntary urination: 5 diseases, Probability: 250.00%
# 79. Skin moles: 5 diseases, Probability: 250.00%
# 80. Excessive growth: 5 diseases, Probability: 250.00%
# 81. Irregular appearing scalp: 5 diseases, Probability: 250.00%
# 82. Fluid retention: 5 diseases, Probability: 250.00%
# 83. Elbow weakness: 5 diseases, Probability: 250.00%
# 84. Eye burns or stings: 5 diseases, Probability: 250.00%
# 85. Fears and phobias: 5 diseases, Probability: 250.00%
# 86. Skin irritation: 5 diseases, Probability: 250.00%
# 87. Emotional symptoms: 5 diseases, Probability: 250.00%
# 88. Low back weakness: 5 diseases, Probability: 250.00%
# 89. Vaginal pain: 4 diseases, Probability: 200.00%
# 90. Seizures: 4 diseases, Probability: 200.00%
# 91. Cramps and spasms: 4 diseases, Probability: 200.00%
# 92. Mass on eyelid: 4 diseases, Probability: 200.00%
# 93. Warts: 4 diseases, Probability: 200.00%
# 94. Intermenstrual bleeding: 4 diseases, Probability: 200.00%
# 95. Vaginal discharge: 4 diseases, Probability: 200.00%
# 96. Difficulty in swallowing: 4 diseases, Probability: 200.00%
# 97. Wrist swelling: 4 diseases, Probability: 200.00%
# 98. Lower abdominal pain: 4 diseases, Probability: 200.00%
# 99. Blood in urine: 4 diseases, Probability: 200.00%
# 100. Leg weakness: 4 diseases, Probability: 200.00%
# 101. Itchy eyelid: 4 diseases, Probability: 200.00%
# 102. Hand or finger swelling: 4 diseases, Probability: 200.00%
# 103. Muscle pain: 4 diseases, Probability: 200.00%
# 104. Loss of sex drive: 4 diseases, Probability: 200.00%
# 105. Long menstrual periods: 4 diseases, Probability: 200.00%
# 106. Absence of menstruation: 4 diseases, Probability: 200.00%
# 107. Muscle swelling: 4 diseases, Probability: 200.00%
# 108. Diarrhea: 3 diseases, Probability: 150.00%
# 109. Abusing alcohol: 3 diseases, Probability: 150.00%
# 110. Restlessness: 3 diseases, Probability: 150.00%
# 111. White discharge from eye: 3 diseases, Probability: 150.00%
# 112. Blindness: 3 diseases, Probability: 150.00%
# 113. Lip swelling: 3 diseases, Probability: 150.00%
# 114. Pain in testicles: 3 diseases, Probability: 150.00%
# 115. Bones are painful: 3 diseases, Probability: 150.00%
# 116. Leg cramps or spasms: 3 diseases, Probability: 150.00%
# 117. Unpredictable menstruation: 3 diseases, Probability: 150.00%
# 118. Fainting: 3 diseases, Probability: 150.00%
# 119. Foot or toe swelling: 3 diseases, Probability: 150.00%
# 120. Hostile behavior: 3 diseases, Probability: 150.00%
# 121. Symptoms of the kidneys: 3 diseases, Probability: 150.00%
# 122. Vaginal itching: 3 diseases, Probability: 150.00%
# 123. Feeling hot and cold: 3 diseases, Probability: 150.00%
# 124. Decreased appetite: 3 diseases, Probability: 150.00%
# 125. Knee swelling: 3 diseases, Probability: 150.00%
# 126. Infertility: 3 diseases, Probability: 150.00%
# 127. Focal weakness: 3 diseases, Probability: 150.00%
# 128. Irregular heartbeat: 3 diseases, Probability: 150.00%
# 129. Low self-esteem: 3 diseases, Probability: 150.00%
# 130. Abnormal movement of eyelid: 3 diseases, Probability: 150.00%
# 131. Skin on leg or foot looks infected: 3 diseases, Probability: 150.00%
# 132. Rib pain: 3 diseases, Probability: 150.00%
# 133. Leg swelling: 3 diseases, Probability: 150.00%
# 134. Shoulder swelling: 3 diseases, Probability: 150.00%
# 135. Sweating: 2 diseases, Probability: 100.00%
# 136. Diminished hearing: 2 diseases, Probability: 100.00%
# 137. Hot flashes: 2 diseases, Probability: 100.00%
# 138. Arm stiffness or tightness: 2 diseases, Probability: 100.00%
# 139. Eyelid swelling: 2 diseases, Probability: 100.00%
# 140. Heavy menstrual flow: 2 diseases, Probability: 100.00%
# 141. Swelling of scrotum: 2 diseases, Probability: 100.00%
# 142. Vaginal bleeding after menopause: 2 diseases, Probability: 100.00%
# 143. Penile discharge: 2 diseases, Probability: 100.00%
# 144. Irritable infant: 2 diseases, Probability: 100.00%
# 145. Hand or finger weakness: 2 diseases, Probability: 100.00%
# 146. Bleeding or discharge from nipple: 2 diseases, Probability: 100.00%
# 147. Excessive appetite: 2 diseases, Probability: 100.00%
# 148. Vulvar sore: 2 diseases, Probability: 100.00%
# 149. Painful sinuses: 2 diseases, Probability: 100.00%
# 150. Nasal congestion: 2 diseases, Probability: 100.00%
# 151. Burning abdominal pain: 2 diseases, Probability: 100.00%
# 152. Neck cramps or spasms: 2 diseases, Probability: 100.00%
# 153. Feeling ill: 2 diseases, Probability: 100.00%
# 154. Suprapubic pain: 2 diseases, Probability: 100.00%
# 155. Skin pain: 2 diseases, Probability: 100.00%
# 156. Sore throat: 2 diseases, Probability: 100.00%
# 157. Infrequent menstruation: 2 diseases, Probability: 100.00%
# 158. Unwanted hair: 2 diseases, Probability: 100.00%
# 159. Hemoptysis: 2 diseases, Probability: 100.00%
# 160. Lymphedema: 2 diseases, Probability: 100.00%
# 161. Sleepiness: 2 diseases, Probability: 100.00%
# 162. Symptoms of the face: 2 diseases, Probability: 100.00%
# 163. Stiffness all over: 2 diseases, Probability: 100.00%
# 164. Penis pain: 2 diseases, Probability: 100.00%
# 165. Lack of growth: 2 diseases, Probability: 100.00%
# 166. Penis redness: 2 diseases, Probability: 100.00%
# 167. Palpitations: 2 diseases, Probability: 100.00%
# 168. Back weakness: 2 diseases, Probability: 100.00%
# 169. Eye strain: 2 diseases, Probability: 100.00%
# 170. Foot or toe stiffness or tightness: 2 diseases, Probability: 100.00%
# 171. Pain during intercourse: 2 diseases, Probability: 100.00%
# 172. Nightmares: 2 diseases, Probability: 100.00%
# 173. Hoarse voice: 2 diseases, Probability: 100.00%
# 174. Muscle cramps, contractures, or spasms: 2 diseases, Probability: 100.00%

# %%
# Ask the user for input
user_input = input("Enter a word to match symptoms: ").strip().lower()

# List to hold matching symptoms
matching_symptoms = []

# Iterate through the symptom-disease mapping
for symptom in symptom_disease_map.keys():
    if user_input in symptom.lower():
        matching_symptoms.append(symptom)

# Print matching symptoms
if matching_symptoms:
    print(f"Symptoms matching '{user_input}':")
    for idx, symptom in enumerate(matching_symptoms, 1):
        print(f"{idx}. {symptom}")

    # Ask the user which symptom they have
    selection = input("Enter the number corresponding to the symptom you have: ")

    # Validate user selection
    if selection.isdigit() and 1 <= int(selection) <= len(matching_symptoms):
        user_input_symptom = matching_symptoms[int(selection) - 1]
        print(f"You selected: {user_input_symptom}")
    else:
        print("Invalid selection. Please enter a number corresponding to the symptom.")
else:
    print(f"No symptoms matching '{user_input}' found.")
# Out:
# Enter a word to match symptoms: back
# Symptoms matching 'back':
# 1. Back pain
# 2. Low back pain
# 3. Back weakness
# 4. Low back weakness
# 5. Back stiffness or tightness
# 6. Back cramps or spasms
# 7. Back mass or lump
# Enter the number corresponding to the symptom you have: 3
# You selected: Back weakness

# %%
# Define a variable to track whether diseases are found
diseases_found = False

# Initialize a set to hold encountered diseases
encountered_diseases = set()

# Initialize a list to hold confirmed symptoms
confirmed_symptoms = []

# Iterate over sorted symptoms in ascending order of probability
for symptom, probability in sorted_symptoms:
    # Check if the symptom has already been confirmed
    if symptom in confirmed_symptoms:
        continue

    response = input(f"Do you have {symptom}? (yes/no): ").lower().strip()
    if response == 'yes':
        confirmed_symptoms.append(symptom)
        # Find diseases associated with confirmed symptoms
        matching_diseases = set()
        for disease, symptoms in symptom_disease_map.items():
            if all(symptom in confirmed_symptoms for symptom in symptoms):
                matching_diseases.add(disease)

        # Print diseases containing confirmed symptoms
        if matching_diseases:
            print("Predicted Diseases:")
            for disease in matching_diseases:
                print(disease)
            diseases_found = True
            break
        else:
            print("No diseases found containing the confirmed symptoms.")
    elif response == 'no':
        continue
    else:
        print("Invalid response. Please enter 'yes' or 'no'.")

# If diseases are found, calculate NDCG score
if diseases_found:
    # Calculate NDCG score (NDCG calculation code goes here)
    ndcg_score = 0.0  # Placeholder for actual NDCG calculation
    print("NDCG Score:", ndcg_score)
else:
    print("No diseases predicted.")
# Out:
# Do you have Groin pain? (yes/no): yes
# No diseases found containing the confirmed symptoms.
# Do you have Headache? (yes/no): yes
# No diseases found containing the confirmed symptoms.
# Do you have Knee pain? (yes/no): yes
# No diseases found containing the confirmed symptoms.
# No diseases predicted.

# %%
# Define a variable to track whether diseases are found
diseases_found = False

# Initialize a set to hold encountered diseases
encountered_diseases = set()

# Initialize a set to hold all symptoms found in associated diseases
other_symptoms = set()

# Iterate over sorted symptoms in ascending order of probability
for symptom, probability in sorted_symptoms:
    # Check if the symptom has already been confirmed
    if symptom == user_input_symptom:
        continue

    response = input(f"Do you have {symptom}? (yes/no): ").lower().strip()
    if response == 'yes':
        # Combine the confirmed symptom with the user input symptom
        combined_symptoms = [user_input_symptom, symptom]

        # Find diseases associated with both symptoms
        combined_diseases = []
        for index, row in df.iterrows():
            disease_tag = row['Disease Tag']
            symptoms = row['Symptoms']
            if 'Wrist pain' in symptoms and 'Pain in eye' in symptoms:
                if disease_tag not in encountered_diseases:
                    combined_diseases.append(disease_tag)
                    encountered_diseases.add(disease_tag)
                # Add other symptoms of the disease to the set
                other_symptoms.update(symptoms)

        # Print diseases containing both symptoms
        if combined_diseases:
            print(f"Diseases containing both '{user_input_symptom}' and '{symptom}':")
            for idx, disease in enumerate(combined_diseases, 1):
                print(f"{idx}. {disease}")
            diseases_found = True
            break
        else:
            print(f"No diseases found containing both '{user_input_symptom}' and '{symptom}'.")
    elif response == 'no':
        continue
    else:
        print("Invalid response. Please enter 'yes' or 'no'.")

# If diseases are found, display other symptoms in associated diseases
if diseases_found:
    print("\nOther Symptoms in Associated Diseases:")
    for idx, symptom in enumerate(other_symptoms, 1):
        print(f"{idx}. {symptom}")
# Out:
# Do you have Sweating? (yes/no): yes
# Diseases containing both 'Back weakness' and 'Sweating':
# 1. Air embolism
# 2. Gas gangrene
# 3. Fat embolism
# 4. Chancroid
# 5. Chagas disease
# 6. Dengue fever
#
# Other Symptoms in Associated Diseases:
# 1. Excessive urination at night
# 2. Fever
# 3. Ankle pain
# 4. Sore throat
# 5. Fatigue
# 6. Sharp abdominal pain
# 7. Pain in eye
# 8. Pain during pregnancy
# 9. Joint stiffness or tightness
# 10. Pain or soreness of breast
# 11. Knee lump or mass
# 12. Excessive anger
# 13. Facial pain
# 14. Shoulder cramps or spasms
# 15. Wrist pain

# %%
###############################################
