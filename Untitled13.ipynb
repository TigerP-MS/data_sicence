# %%
import pandas as pd
import pickle
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the data from the pickled file
file_path = '/content/drive/My Drive/synthetic_dataset/goal_set.p'
with open(file_path, 'rb') as file:
    consultation_data = pickle.load(file)

# Extract 'train' data
train_data = consultation_data['train']

# Lists to hold disease tags and symptoms
disease_tags = []
symptoms = []

# Extract disease tag and symptoms from each consultation in the 'train' data
for item in train_data:
    # Extract disease tag
    disease_tags.append(item['disease_tag'])

    # Extract symptoms
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms
    symptoms.append(all_symptoms)

# Create a DataFrame
df = pd.DataFrame({
    'Disease Tag': disease_tags,
    'Symptoms': symptoms
})

# Dictionary to hold symptoms and connected diseases
symptom_to_diseases = {}
symptom_counts = {}

# Populate the symptom to diseases mapping and count symptoms
for index, row in df.iterrows():
    disease_tag = row['Disease Tag']
    all_symptoms = row['Symptoms']

    for symptom in all_symptoms:
        if symptom not in symptom_to_diseases:
            symptom_to_diseases[symptom] = set()
            symptom_counts[symptom] = 0
        symptom_to_diseases[symptom].add(disease_tag)
        symptom_counts[symptom] += 1

# Convert the dictionary to a DataFrame
symptom_to_diseases_df = pd.DataFrame([
    {'Symptom': symptom, 'Connected Diseases': list(diseases), 'Count': symptom_counts[symptom]}
    for symptom, diseases in symptom_to_diseases.items()
])

# Sort the DataFrame by the frequency of symptoms in ascending order
symptom_to_diseases_df = symptom_to_diseases_df.sort_values(by='Count', ascending=True)

# Display the DataFrame
print(symptom_to_diseases_df)
# Out:
# Mounted at /content/drive
#                               Symptom  \
# 263                      Feeling cold
# 265                      Pus in urine
# 261   Hand or finger cramps or spasms
# 244       Back stiffness or tightness
# 228                     Pus in sputum
# ..                                ...
# 62   Depressive or psychotic symptoms
# 1                   Diminished vision
# 5                           Back pain
# 3                         Pain in eye
# 21                          Skin rash
#
#                                     Connected Diseases  Count
# 263                           [Chronic kidney disease]      1
# 265                            [Dissociative disorder]      2
# 261                   [Diabetic peripheral neuropathy]      3
# 244                                [Chronic back pain]      3
# 228                          [Endometrial hyperplasia]      3
# ..                                                 ...    ...
# 62   [Eating disorder, Anxiety, Factitious disorder...   1716
# 1    [Corneal abrasion, Endophthalmitis, Chalazion,...   1718
# 5    [Fracture of the pelvis, Concussion, Fracture ...   1803
# 3    [Corneal abrasion, Endophthalmitis, Chalazion,...   2449
# 21   [Eczema, Actinic keratosis, Acne, Allergy, Dys...   2471
#
# [266 rows x 3 columns]

# %%
df
# Out:
#                                     Disease Tag  \
# 0      Central retinal artery or vein occlusion
# 1                     Degenerative disc disease
# 2                          Diabetic retinopathy
# 3                             Chronic back pain
# 4                                  Air embolism
# ...                                         ...
# 23995                                Concussion
# 23996                          Cushing syndrome
# 23997                              Fibromyalgia
# 23998                              Dengue fever
# 23999                                 Flat feet
#
#                                                 Symptoms
# 0      [Spots or clouds in vision, Diminished vision,...
# 1      [Shoulder pain, Back pain, Low back pain, Neck...
# 2                        [Foreign body sensation in eye]
# 3                  [Low back pain, Back pain, Side pain]
# 4      [Wrist pain, Pain in eye, Shoulder cramps or s...
# ...                                                  ...
# 23995                      [Neck pain, Headache, Nausea]
# 23996                                      [Weight gain]
# 23997  [Low back pain, Back pain, Ache all over, Shou...
# 23998  [Fever, Sore throat, Wrist pain, Pain during p...
# 23999          [Knee pain, Foot or toe pain, Ankle pain]
#
# [24000 rows x 2 columns]

# %%
# Iterate over each row in the DataFrame
for index, row in symptom_to_diseases_df.iterrows():
    symptom = row['Symptom']
    connected_diseases = row['Connected Diseases']

    # Print the symptom
    print(f"Symptom: {symptom}")

    # Print each associated disease
    print("Associated diseases:")
    for disease in connected_diseases:
        print("- " + disease)

    print()  # Print a blank line for separation
# Out:
# Symptom: Feeling cold
# Associated diseases:
# - Chronic kidney disease
#
# Symptom: Pus in urine
# Associated diseases:
# - Dissociative disorder
#
# Symptom: Hand or finger cramps or spasms
# Associated diseases:
# - Diabetic peripheral neuropathy
#
# Symptom: Back stiffness or tightness
# Associated diseases:
# - Chronic back pain
#
# Symptom: Pus in sputum
# Associated diseases:
# - Endometrial hyperplasia
#
# Symptom: Incontinence of stool
# Associated diseases:
# - Decubitus ulcer
#
# Symptom: Itching of scrotum
# Associated diseases:
# - Cushing syndrome
#
# Symptom: Back weakness
# Associated diseases:
# - Endometrial hyperplasia
# - Dissociative disorder
#
# Symptom: Frequent menstruation
# Associated diseases:
# - Fibrocystic breast disease
#
# Symptom: Nose deformity
# Associated diseases:
# - Acne
#
# Symptom: Abnormal size or shape of ear
# Associated diseases:
# - Endometrial hyperplasia
#
# Symptom: Scanty menstrual flow
# Associated diseases:
# - Female infertility of unknown cause
#
# Symptom: Disturbance of smell or taste
# Associated diseases:
# - Decubitus ulcer
#
# Symptom: Bladder mass
# Associated diseases:
# - Cushing syndrome
#
# Symptom: Irregular belly button
# Associated diseases:
# - Female infertility of unknown cause
#
# Symptom: Hysterical behavior
# Associated diseases:
# - Drug abuse cocaine
#
# Symptom: Back mass or lump
# Associated diseases:
# - Fracture of the rib
#
# Symptom: Bowlegged or knock-kneed
# Associated diseases:
# - Acariasis
#
# Symptom: Back cramps or spasms
# Associated diseases:
# - Chronic back pain
#
# Symptom: Hip stiffness or tightness
# Associated diseases:
# - Diabetes insipidus
#
# Symptom: Nightmares
# Associated diseases:
# - Adjustment reaction
# - Drug abuse cocaine
#
# Symptom: Arm weakness
# Associated diseases:
# - Carpal tunnel syndrome
#
# Symptom: Too little hair
# Associated diseases:
# - Acne
#
# Symptom: Mass on vulva
# Associated diseases:
# - Endometrial cancer
#
# Symptom: Unusual color or odor to urine
# Associated diseases:
# - Chronic kidney disease
#
# Symptom: Premature ejaculation
# Associated diseases:
# - Erectile dysfunction
#
# Symptom: Cross-eyed
# Associated diseases:
# - Acariasis
#
# Symptom: Sinus congestion
# Associated diseases:
# - Cystic Fibrosis
#
# Symptom: Diaper rash
# Associated diseases:
# - Contact dermatitis
#
# Symptom: Bleeding gums
# Associated diseases:
# - Cystic Fibrosis
#
# Symptom: Muscle cramps, contractures, or spasms
# Associated diseases:
# - Alzheimer disease
# - Graves disease
#
# Symptom: Increased heart rate
# Associated diseases:
# - Anxiety
#
# Symptom: Drainage in throat
# Associated diseases:
# - Cystic Fibrosis
#
# Symptom: Muscle swelling
# Associated diseases:
# - Endometrial hyperplasia
# - Cushing syndrome
# - Dissociative disorder
# - Cyst of the eyelid
#
# Symptom: Infrequent menstruation
# Associated diseases:
# - Endometrial cancer
# - Cushing syndrome
#
# Symptom: Bleeding from eye
# Associated diseases:
# - Diabetic retinopathy
#
# Symptom: Temper problems
# Associated diseases:
# - Adjustment reaction
#
# Symptom: Swollen abdomen
# Associated diseases:
# - Epididymitis
#
# Symptom: Infant spitting up
# Associated diseases:
# - Diaper rash
#
# Symptom: Swollen or red tonsils
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: Vomiting blood
# Associated diseases:
# - Eating disorder
#
# Symptom: Pain during intercourse
# Associated diseases:
# - Erectile dysfunction
# - Female infertility of unknown cause
#
# Symptom: Poor circulation
# Associated diseases:
# - Diabetic peripheral neuropathy
#
# Symptom: Ankle stiffness or tightness
# Associated diseases:
# - Adhesive capsulitis of the shoulder
#
# Symptom: Eye deviation
# Associated diseases:
# - Central retinal artery or vein occlusion
#
# Symptom: Skin on arm or hand looks infected
# Associated diseases:
# - Adhesive capsulitis of the shoulder
#
# Symptom: Feeling hot and cold
# Associated diseases:
# - Amyloidosis
# - Acariasis
# - Epidural hemorrhage
#
# Symptom: Pulling at ears
# Associated diseases:
# - Diaper rash
#
# Symptom: Hand or finger stiffness or tightness
# Associated diseases:
# - Carpal tunnel syndrome
#
# Symptom: Itchy scalp
# Associated diseases:
# - Dermatitis due to sun exposure
#
# Symptom: Polyuria
# Associated diseases:
# - Diabetic ketoacidosis
#
# Symptom: Swollen tongue
# Associated diseases:
# - Allergy
#
# Symptom: Mass in scrotum
# Associated diseases:
# - Epididymitis
#
# Symptom: Low back weakness
# Associated diseases:
# - Dissociative disorder
# - Carbon monoxide poisoning
# - Epidural hemorrhage
# - Cushing syndrome
# - Endometrial hyperplasia
#
# Symptom: Hoarse voice
# Associated diseases:
# - Conductive hearing loss
# - Essential tremor
#
# Symptom: Problems during pregnancy
# Associated diseases:
# - Chickenpox
#
# Symptom: Knee weakness
# Associated diseases:
# - Chondromalacia of the patella
#
# Symptom: Spotting or bleeding during pregnancy
# Associated diseases:
# - Gonorrhea
#
# Symptom: Unwanted hair
# Associated diseases:
# - Female infertility of unknown cause
# - Acanthosis nigricans
#
# Symptom: Throat swelling
# Associated diseases:
# - Drug reaction
#
# Symptom: Foot or toe stiffness or tightness
# Associated diseases:
# - Diabetic peripheral neuropathy
# - Flat feet
#
# Symptom: Apnea
# Associated diseases:
# - Acanthosis nigricans
#
# Symptom: Chills
# Associated diseases:
# - Endometriosis
#
# Symptom: Sneezing
# Associated diseases:
# - Conjunctivitis due to allergy
#
# Symptom: Hemoptysis
# Associated diseases:
# - Graves disease
# - Cystic Fibrosis
#
# Symptom: Thirst
# Associated diseases:
# - Diabetic ketoacidosis
#
# Symptom: Ankle swelling
# Associated diseases:
# - Gout
#
# Symptom: Difficulty eating
# Associated diseases:
# - Eating disorder
#
# Symptom: Stiffness all over
# Associated diseases:
# - Adhesive capsulitis of the shoulder
# - Ankylosing spondylitis
#
# Symptom: Wrist stiffness or tightness
# Associated diseases:
# - De Quervain disease
#
# Symptom: Chest tightness
# Associated diseases:
# - Acute stress reaction
#
# Symptom: Symptoms of the face
# Associated diseases:
# - Actinic keratosis
# - Dermatitis due to sun exposure
#
# Symptom: Eye strain
# Associated diseases:
# - Amyloidosis
# - Carcinoid syndrome
#
# Symptom: Foot or toe lump or mass
# Associated diseases:
# - Dyshidrosis
#
# Symptom: Fluid in ear
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: Lack of growth
# Associated diseases:
# - Conductive hearing loss
# - Dermatitis due to sun exposure
#
# Symptom: Dry or flaky scalp
# Associated diseases:
# - Dyshidrosis
#
# Symptom: Muscle stiffness or tightness
# Associated diseases:
# - Cerebral edema
#
# Symptom: Symptoms of bladder
# Associated diseases:
# - Cystitis
#
# Symptom: Knee stiffness or tightness
# Associated diseases:
# - Chondromalacia of the patella
#
# Symptom: Emotional symptoms
# Associated diseases:
# - Carbon monoxide poisoning
# - Epidural hemorrhage
# - Diabetes insipidus
# - Cushing syndrome
# - Acariasis
#
# Symptom: Arm stiffness or tightness
# Associated diseases:
# - Essential tremor
# - Extrapyramidal effect of drugs
#
# Symptom: Kidney mass
# Associated diseases:
# - Acute kidney injury
#
# Symptom: Neck cramps or spasms
# Associated diseases:
# - Granuloma inguinale
# - Carcinoid syndrome
#
# Symptom: Elbow weakness
# Associated diseases:
# - Factitious disorder
# - Epidural hemorrhage
# - Diabetes insipidus
# - Cushing syndrome
# - Acariasis
#
# Symptom: Neck stiffness or tightness
# Associated diseases:
# - Extrapyramidal effect of drugs
#
# Symptom: Bleeding or discharge from nipple
# Associated diseases:
# - Female infertility of unknown cause
# - Fibrocystic breast disease
#
# Symptom: Elbow cramps or spasms
# Associated diseases:
# - Factitious disorder
# - Carbon monoxide poisoning
# - Cyst of the eyelid
# - Diabetes insipidus
# - Cushing syndrome
# - Endometrial hyperplasia
#
# Symptom: Absence of menstruation
# Associated diseases:
# - Endometrial cancer
# - Female infertility of unknown cause
# - Endometriosis
# - Fibrocystic breast disease
#
# Symptom: Symptoms of prostate
# Associated diseases:
# - Erectile dysfunction
#
# Symptom: Penis pain
# Associated diseases:
# - Erectile dysfunction
# - Chlamydia
#
# Symptom: Muscle weakness
# Associated diseases:
# - Amyotrophic lateral sclerosis ALS
#
# Symptom: Fears and phobias
# Associated diseases:
# - Anxiety
# - Drug abuse cocaine
# - Alzheimer disease
# - Adjustment reaction
# - Essential tremor
#
# Symptom: Bones are painful
# Associated diseases:
# - Chondromalacia of the patella
# - Fracture of the pelvis
# - Fracture of the rib
#
# Symptom: Hurts to breath
# Associated diseases:
# - Fracture of the rib
#
# Symptom: Painful sinuses
# Associated diseases:
# - Endophthalmitis
# - Essential tremor
#
# Symptom: Wrinkles on skin
# Associated diseases:
# - Cyst of the eyelid
#
# Symptom: Irritable infant
# Associated diseases:
# - Chickenpox
# - Diaper rash
#
# Symptom: Skin pain
# Associated diseases:
# - Erythema multiforme
# - Decubitus ulcer
#
# Symptom: Feet turned in
# Associated diseases:
# - Flat feet
#
# Symptom: Penis redness
# Associated diseases:
# - Gonorrhea
# - Decubitus ulcer
#
# Symptom: Long menstrual periods
# Associated diseases:
# - Endometrial cancer
# - Acne
# - Female infertility of unknown cause
# - Fibrocystic breast disease
#
# Symptom: Vulvar sore
# Associated diseases:
# - Granuloma inguinale
# - Carcinoid syndrome
#
# Symptom: Irregular heartbeat
# Associated diseases:
# - Central retinal artery or vein occlusion
# - Anxiety
# - Graves disease
#
# Symptom: Skin on leg or foot looks infected
# Associated diseases:
# - Diabetic peripheral neuropathy
# - Dyshidrosis
# - Decubitus ulcer
#
# Symptom: Itchy eyelid
# Associated diseases:
# - Diabetes insipidus
# - Cat scratch disease
# - Factitious disorder
# - Carcinoid syndrome
#
# Symptom: Wrist lump or mass
# Associated diseases:
# - Ganglion cyst
#
# Symptom: Restlessness
# Associated diseases:
# - Adjustment reaction
# - Alzheimer disease
# - Extrapyramidal effect of drugs
#
# Symptom: Shoulder swelling
# Associated diseases:
# - Adhesive capsulitis of the shoulder
# - Granuloma inguinale
# - Carcinoid syndrome
#
# Symptom: Eyelid swelling
# Associated diseases:
# - Corneal abrasion
# - Chalazion
#
# Symptom: Lymphedema
# Associated diseases:
# - Diabetic peripheral neuropathy
# - Connective tissue disorder
#
# Symptom: Hand or finger lump or mass
# Associated diseases:
# - Ganglion cyst
#
# Symptom: Mouth ulcer
# Associated diseases:
# - Erythema multiforme
#
# Symptom: Frontal headache
# Associated diseases:
# - Carbon monoxide poisoning
#
# Symptom: Hot flashes
# Associated diseases:
# - Endometrial cancer
# - Endometriosis
#
# Symptom: Nailbiting
# Associated diseases:
# - Factitious disorder
# - Granuloma inguinale
# - Carcinoid syndrome
# - Amyloidosis
# - Diabetes insipidus
# - Cushing syndrome
#
# Symptom: Skin irritation
# Associated diseases:
# - Eczema
# - Actinic keratosis
# - Fibrocystic breast disease
# - Diaper rash
# - Contact dermatitis
#
# Symptom: Burning abdominal pain
# Associated diseases:
# - Acute stress reaction
# - Endometriosis
#
# Symptom: Leg cramps or spasms
# Associated diseases:
# - Amyotrophic lateral sclerosis ALS
# - Graves disease
# - Fibrocystic breast disease
#
# Symptom: Loss of sex drive
# Associated diseases:
# - Erectile dysfunction
# - Female infertility of unknown cause
# - Granuloma inguinale
# - Carcinoid syndrome
#
# Symptom: Warts
# Associated diseases:
# - Eczema
# - Acne
# - Actinic keratosis
# - Acanthosis nigricans
#
# Symptom: Double vision
# Associated diseases:
# - Concussion
# - Central retinal artery or vein occlusion
# - Acute glaucoma
# - Corneal disorder
# - Diabetic retinopathy
#
# Symptom: Painful menstruation
# Associated diseases:
# - Endometriosis
#
# Symptom: Difficulty breathing
# Associated diseases:
# - Fluid overload
#
# Symptom: Palpitations
# Associated diseases:
# - Anxiety
# - Graves disease
#
# Symptom: Excessive growth
# Associated diseases:
# - Factitious disorder
# - Granuloma inguinale
# - Carcinoid syndrome
# - Epidural hemorrhage
# - Acariasis
#
# Symptom: Redness in ear
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: Wrist weakness
# Associated diseases:
# - Factitious disorder
# - Granuloma inguinale
# - Carcinoid syndrome
# - Amyloidosis
# - Epidural hemorrhage
# - Diabetes insipidus
# - Acariasis
#
# Symptom: Sleepiness
# Associated diseases:
# - Concussion
# - Carbon monoxide poisoning
#
# Symptom: Plugged feeling in ear
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: Ringing in ear
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: White discharge from eye
# Associated diseases:
# - Ectropion
# - Corneal abrasion
# - Corneal disorder
#
# Symptom: Congestion in chest
# Associated diseases:
# - Amyloidosis
#
# Symptom: Hand or finger weakness
# Associated diseases:
# - Carpal tunnel syndrome
# - Amyotrophic lateral sclerosis ALS
#
# Symptom: Decreased heart rate
# Associated diseases:
# - Cushing syndrome
#
# Symptom: Knee swelling
# Associated diseases:
# - Ganglion cyst
# - Gout
# - Chondromalacia of the patella
#
# Symptom: Coryza
# Associated diseases:
# - Erythema multiforme
#
# Symptom: Hostile behavior
# Associated diseases:
# - Adjustment reaction
# - Alzheimer disease
# - Drug abuse cocaine
#
# Symptom: Intermenstrual bleeding
# Associated diseases:
# - Endometrial cancer
# - Endometriosis
# - Fibrocystic breast disease
# - Cystic Fibrosis
#
# Symptom: Ear pain
# Associated diseases:
# - Conductive hearing loss
#
# Symptom: Sweating
# Associated diseases:
# - Graves disease
# - Conversion disorder
#
# Symptom: Leg swelling
# Associated diseases:
# - Ganglion cyst
# - Gout
# - Fluid overload
#
# Symptom: Wrist swelling
# Associated diseases:
# - Gout
# - Ganglion cyst
# - De Quervain disease
# - Carpal tunnel syndrome
#
# Symptom: Arm swelling
# Associated diseases:
# - Cat scratch disease
#
# Symptom: Arm lump or mass
# Associated diseases:
# - Cat scratch disease
#
# Symptom: Shoulder stiffness or tightness
# Associated diseases:
# - Adhesive capsulitis of the shoulder
#
# Symptom: Vaginal itching
# Associated diseases:
# - Gonorrhea
# - Endometrial cancer
# - Chlamydia
#
# Symptom: Groin mass
# Associated diseases:
# - Cat scratch disease
#
# Symptom: Low self-esteem
# Associated diseases:
# - Adjustment reaction
# - Conductive hearing loss
# - Dissociative disorder
#
# Symptom: Blindness
# Associated diseases:
# - Central retinal artery or vein occlusion
# - Acute glaucoma
# - Diabetic retinopathy
#
# Symptom: Elbow pain
# Associated diseases:
# - Chondromalacia of the patella
# - Adhesive capsulitis of the shoulder
# - Central retinal artery or vein occlusion
# - Carpal tunnel syndrome
# - Ankylosing spondylitis
#
# Symptom: Hand or finger swelling
# Associated diseases:
# - Gout
# - De Quervain disease
# - Carpal tunnel syndrome
# - Fluid overload
#
# Symptom: Nasal congestion
# Associated diseases:
# - Conjunctivitis due to allergy
# - Diaper rash
#
# Symptom: Irregular appearing scalp
# Associated diseases:
# - Eczema
# - Acne
# - Actinic keratosis
# - Alzheimer disease
# - Dermatitis due to sun exposure
#
# Symptom: Feeling ill
# Associated diseases:
# - Connective tissue disorder
# - Cystic Fibrosis
#
# Symptom: Foot or toe swelling
# Associated diseases:
# - Gout
# - Diabetic peripheral neuropathy
# - Alzheimer disease
# - Extrapyramidal effect of drugs
# - Adjustment reaction
#
# Symptom: Lip swelling
# Associated diseases:
# - Drug reaction
# - Factitious disorder
# - Allergy
#
# Symptom: Joint pain
# Associated diseases:
# - Chondromalacia of the patella
# - Gout
# - Encephalitis
# - Connective tissue disorder
# - Degenerative disc disease
# - Ankylosing spondylitis
#
# Symptom: Eyelid lesion or rash
# Associated diseases:
# - Corneal abrasion
# - Chalazion
# - Cyst of the eyelid
# - Corneal disorder
# - Ectropion
#
# Symptom: Pain in testicles
# Associated diseases:
# - Erectile dysfunction
# - Epididymitis
# - Chickenpox
#
# Symptom: Leg weakness
# Associated diseases:
# - Encephalitis
# - Amyotrophic lateral sclerosis ALS
# - Chronic back pain
# - Guillain Barre syndrome
#
# Symptom: Swelling of scrotum
# Associated diseases:
# - Acariasis
# - Epididymitis
#
# Symptom: Vaginal bleeding after menopause
# Associated diseases:
# - Endometrial cancer
# - Endometrial hyperplasia
#
# Symptom: Diarrhea
# Associated diseases:
# - Diabetic ketoacidosis
# - Carbon monoxide poisoning
# - Diaper rash
#
# Symptom: Vaginal pain
# Associated diseases:
# - Gonorrhea
# - Chlamydia
# - Endometriosis
# - Granuloma inguinale
#
# Symptom: Involuntary urination
# Associated diseases:
# - Carcinoid syndrome
# - Erectile dysfunction
# - Cystitis
# - Endometrial hyperplasia
# - Graves disease
#
# Symptom: Penile discharge
# Associated diseases:
# - Gonorrhea
# - Chlamydia
#
# Symptom: Vaginal discharge
# Associated diseases:
# - Gonorrhea
# - Endometrial hyperplasia
# - Chlamydia
# - Endometrial cancer
#
# Symptom: Infertility
# Associated diseases:
# - Female infertility of unknown cause
# - Endometriosis
# - Acanthosis nigricans
#
# Symptom: Foreign body sensation in eye
# Associated diseases:
# - Corneal abrasion
# - Chalazion
# - Central retinal artery or vein occlusion
# - Acute glaucoma
# - Corneal disorder
# - Ectropion
# - Diabetic retinopathy
#
# Symptom: Diminished hearing
# Associated diseases:
# - Conductive hearing loss
# - Epidural hemorrhage
#
# Symptom: Difficulty in swallowing
# Associated diseases:
# - Diabetes insipidus
# - Connective tissue disorder
# - Erythema multiforme
# - Amyotrophic lateral sclerosis ALS
#
# Symptom: Sore throat
# Associated diseases:
# - Dengue fever
# - Conversion disorder
#
# Symptom: Pelvic pain
# Associated diseases:
# - Chronic pain disorder
# - Endometrial cancer
# - Endometriosis
# - Chlamydia
# - Cystitis
# - Endometrial hyperplasia
#
# Symptom: Difficulty speaking
# Associated diseases:
# - Fracture of the pelvis
# - Concussion
# - Cerebral edema
# - Conductive hearing loss
# - Alzheimer disease
# - Guillain Barre syndrome
# - Amyotrophic lateral sclerosis ALS
# - Decubitus ulcer
#
# Symptom: Abusing alcohol
# Associated diseases:
# - Alcohol intoxication
# - Eating disorder
# - Drug abuse cocaine
#
# Symptom: Peripheral edema
# Associated diseases:
# - Fluid overload
# - Allergy
# - Acute kidney injury
# - De Quervain disease
# - Chronic kidney disease
# - Drug reaction
#
# Symptom: Mass on eyelid
# Associated diseases:
# - Aphakia
# - Flat feet
#
# Symptom: Abnormal appearing skin
# Associated diseases:
# - Drug reaction
# - Eczema
# - Actinic keratosis
# - Acne
# - Allergy
# - Amyloidosis
# - Contact dermatitis
# - Dermatitis due to sun exposure
# - Chickenpox
# - Dyshidrosis
#
# Symptom: Eye redness
# Associated diseases:
# - Corneal abrasion
# - Chalazion
# - Endophthalmitis
# - Ectropion
# - Acute glaucoma
# - Corneal disorder
# - Chickenpox
# - Aphakia
# - Conjunctivitis due to allergy
# - Diabetic retinopathy
#
# Symptom: Nausea
# Associated diseases:
# - Concussion
# - Carbon monoxide poisoning
# - Granuloma inguinale
# - Fluid overload
# - Alcohol intoxication
# - Cerebral edema
# - Diabetic ketoacidosis
# - Extrapyramidal effect of drugs
# - Acute kidney injury
# - Drug reaction
#
# Symptom: Vomiting
# Associated diseases:
# - Concussion
# - Carbon monoxide poisoning
# - Fluid overload
# - Alcohol intoxication
# - Cerebral edema
# - Erythema multiforme
# - Diabetic ketoacidosis
# - Acute kidney injury
# - Acariasis
# - Drug reaction
#
# Symptom: Fever
# Associated diseases:
# - Amyloidosis
# - Dengue fever
# - Erythema multiforme
# - Cat scratch disease
# - Guillain Barre syndrome
# - Diaper rash
# - Connective tissue disorder
# - Chickenpox
#
# Symptom: Itching of skin
# Associated diseases:
# - Drug reaction
# - Eczema
# - Actinic keratosis
# - Allergy
# - Gonorrhea
# - Erythema multiforme
# - Diaper rash
# - Acariasis
# - Contact dermatitis
# - Chlamydia
# - Chickenpox
# - Dyshidrosis
#
# Symptom: Anxiety and nervousness
# Associated diseases:
# - Eating disorder
# - Anxiety
# - Dissociative disorder
# - Alcohol intoxication
# - Amyloidosis
# - Conversion disorder
# - Extrapyramidal effect of drugs
# - Adjustment reaction
# - Acute stress reaction
#
# Symptom: Depression
# Associated diseases:
# - Eating disorder
# - Anxiety
# - Factitious disorder
# - Dissociative disorder
# - Drug abuse cocaine
# - Alcohol intoxication
# - Conversion disorder
# - Alzheimer disease
# - Adjustment reaction
# - Acute stress reaction
#
# Symptom: Loss of sensation
# Associated diseases:
# - Factitious disorder
# - Complex regional pain syndrome
# - Cat scratch disease
# - Cerebral edema
# - Diabetic peripheral neuropathy
# - Degenerative disc disease
# - Guillain Barre syndrome
# - Encephalitis
# - Carpal tunnel syndrome
# - Chronic back pain
# - Essential tremor
#
# Symptom: Sharp abdominal pain
# Associated diseases:
# - Chronic pain disorder
# - Fluid overload
# - Alcohol intoxication
# - Gonorrhea
# - Endometriosis
# - Diabetic ketoacidosis
# - Acute kidney injury
# - Chlamydia
# - Cystitis
# - Gas gangrene
# - Epididymitis
#
# Symptom: Dizziness
# Associated diseases:
# - Concussion
# - Carbon monoxide poisoning
# - Cerebral edema
# - Conductive hearing loss
# - Acute kidney injury
# - Guillain Barre syndrome
# - Diabetes insipidus
# - Encephalitis
# - Epidural hemorrhage
# - Drug reaction
# - Acute stress reaction
# - Graves disease
# - Essential tremor
#
# Symptom: Wrist pain
# Associated diseases:
# - Gout
# - Ganglion cyst
# - Dengue fever
# - Chagas disease
# - Dyshidrosis
# - Cat scratch disease
# - Erythema multiforme
# - Diaper rash
# - Cyst of the eyelid
# - Acariasis
# - Contact dermatitis
# - Dermatitis due to sun exposure
# - Connective tissue disorder
# - Chickenpox
# - Drug reaction

# %% [markdown]
# # Print symptoms with numbers for user selection
# print("Please select the symptom you have by entering its corresponding number:")
# for i, symptom in enumerate(matching_symptoms, start=1):
#     print(f"{i}. {symptom}")
#
# # Ask the user to select a symptom by its corresponding number
# selected_index = input("Enter the number corresponding to the symptom you have: ")
#
# # Validate the user input
# try:
#     selected_index = int(selected_index)
#     if 1 <= selected_index <= len(matching_symptoms):
#         selected_symptom = matching_symptoms[selected_index - 1]
#         print(f"You selected: {selected_symptom}")
#
#         # Display associated diseases for the selected symptom
#         connected_diseases = symptom_to_diseases_df.loc[symptom_to_diseases_df['Symptom'] == selected_symptom, 'Connected Diseases'].iloc[0]
#         if connected_diseases:
#             print(f"The symptom '{selected_symptom}' is associated with the following diseases:")
#             for disease in connected_diseases:
#                 print("  - " + disease)
#
#                 # Find symptoms associated with the current disease
#                 symptoms_for_disease = symptom_to_diseases_df[symptom_to_diseases_df['Connected Diseases'].apply(lambda x: disease in x)]['Symptom']
#                 # Display associated symptoms for the current disease
#                 if not symptoms_for_disease.empty:
#                     print("    Associated symptoms:")
#                     for symptom in symptoms_for_disease:
#                         print("    - " + symptom)
#                 else:
#                     print("    No symptoms found associated with this disease.")
#         else:
#             print(f"No diseases are associated with the symptom '{selected_symptom}'.")
#     else:
#         print("Invalid input. Please enter a valid number.")
# except ValueError:
#     print("Invalid input. Please enter a valid number.")

# %%
# Initialize a dictionary to store the count of each associated symptom
symptom_counts = {}

# Iterate over all connected diseases
for connected_diseases in symptom_to_diseases_df['Connected Diseases']:
    # Iterate over symptoms associated with the current disease
    for symptom in connected_diseases:
        if symptom in symptom_counts:
            symptom_counts[symptom] += 1
        else:
            symptom_counts[symptom] = 1

# Sort the symptom_counts dictionary by value (count) in ascending order
sorted_symptom_counts = sorted(symptom_counts.items(), key=lambda x: x[1])

# Print the symptoms in ascending order of count
print("Symptoms from smallest count to highest count:")
for symptom, count in sorted_symptom_counts:
    print(f"- {symptom}: {count}")
# Out:
# Symptoms from smallest count to highest count:
# - Chronic kidney disease: 6
# - Decubitus ulcer: 7
# - Aphakia: 8
# - Fibrocystic breast disease: 9
# - Chondromalacia of the patella: 9
# - Female infertility of unknown cause: 10
# - Cystic Fibrosis: 10
# - Central retinal artery or vein occlusion: 10
# - De Quervain disease: 10
# - Dissociative disorder: 11
# - Drug abuse cocaine: 11
# - Adhesive capsulitis of the shoulder: 11
# - Acute glaucoma: 11
# - Diabetic peripheral neuropathy: 12
# - Chronic back pain: 12
# - Endometrial hyperplasia: 12
# - Cushing syndrome: 12
# - Acne: 12
# - Fracture of the rib: 12
# - Acariasis: 12
# - Diabetes insipidus: 12
# - Adjustment reaction: 12
# - Carpal tunnel syndrome: 12
# - Endometrial cancer: 12
# - Erectile dysfunction: 12
# - Contact dermatitis: 12
# - Alzheimer disease: 12
# - Graves disease: 12
# - Anxiety: 12
# - Cyst of the eyelid: 12
# - Diabetic retinopathy: 12
# - Epididymitis: 12
# - Diaper rash: 12
# - Conductive hearing loss: 12
# - Eating disorder: 12
# - Amyloidosis: 12
# - Epidural hemorrhage: 12
# - Dermatitis due to sun exposure: 12
# - Diabetic ketoacidosis: 12
# - Allergy: 12
# - Carbon monoxide poisoning: 12
# - Essential tremor: 12
# - Chickenpox: 12
# - Gonorrhea: 12
# - Acanthosis nigricans: 12
# - Drug reaction: 12
# - Flat feet: 12
# - Endometriosis: 12
# - Conjunctivitis due to allergy: 12
# - Gout: 12
# - Ankylosing spondylitis: 12
# - Acute stress reaction: 12
# - Actinic keratosis: 12
# - Carcinoid syndrome: 12
# - Dyshidrosis: 12
# - Cerebral edema: 12
# - Cystitis: 12
# - Extrapyramidal effect of drugs: 12
# - Acute kidney injury: 12
# - Granuloma inguinale: 12
# - Factitious disorder: 12
# - Chlamydia: 12
# - Amyotrophic lateral sclerosis ALS: 12
# - Fracture of the pelvis: 12
# - Endophthalmitis: 12
# - Erythema multiforme: 12
# - Cat scratch disease: 12
# - Ganglion cyst: 12
# - Corneal abrasion: 12
# - Chalazion: 12
# - Connective tissue disorder: 12
# - Eczema: 12
# - Concussion: 12
# - Corneal disorder: 12
# - Fluid overload: 12
# - Ectropion: 12
# - Conversion disorder: 12
# - Fibromyalgia: 12
# - Chronic pain disorder: 12
# - Degenerative disc disease: 12
# - Alcohol intoxication: 12
# - Encephalitis: 12
# - Guillain Barre syndrome: 12
# - Dengue fever: 12
# - Complex regional pain syndrome: 12
# - Chagas disease: 12
# - Chancroid: 12
# - Fat embolism: 12
# - Air embolism: 12
# - Gas gangrene: 12

# %%
# Initialize a list to store user's input symptoms
user_symptoms = []

while True:
    # Ask the user for a symptom
    user_input = input("Please enter a symptom: ").strip().lower()

    # Find matching symptoms in the dataset
    matching_symptoms = [symptom for symptom in symptom_to_diseases_df['Symptom'] if user_input in symptom.lower()]

    if not matching_symptoms:
        print(f"No symptoms matching '{user_input}' found. Please try again.")
        continue

    # Display matching symptoms for user to choose from
    print(f"Symptoms matching '{user_input}':")
    for idx, symptom in enumerate(matching_symptoms, 1):
        print(f"{idx}. {symptom}")

    # Ask the user which symptom they have
    selected_index = input("Enter the number corresponding to the symptom you have: ")

    # Validate user selection
    try:
        selected_index = int(selected_index)
        if 1 <= selected_index <= len(matching_symptoms):
            chosen_symptom = matching_symptoms[selected_index - 1]
            if chosen_symptom not in user_symptoms:
                user_symptoms.append(chosen_symptom)
                print(f"You selected: {chosen_symptom}")
            else:
                print(f"You have already selected the symptom: {chosen_symptom}. Please choose another symptom.")
                continue
        else:
            print("Invalid selection. Please enter a number corresponding to the symptom.")
            continue
    except ValueError:
        print("Invalid selection. Please enter a number corresponding to the symptom.")
        continue

    # Find diseases associated with all user's input symptoms
    all_symptoms_diseases = [set(symptom_to_diseases_df.loc[symptom_to_diseases_df['Symptom'] == symptom]['Connected Diseases'].explode()) for symptom in user_symptoms]
    common_diseases = set.intersection(*all_symptoms_diseases)

    if len(common_diseases) == 1:
        # If only one disease is found, display it and exit
        print("Only one disease found associated with all symptoms entered:")
        print("- " + common_diseases.pop())
        break

    # If no diseases are associated with all the symptoms entered, prompt the user to enter more symptoms
    if not common_diseases:
        print("No diseases found associated with all the symptoms entered. Please enter more symptoms.")
        continue

    # Show possible symptoms associated with the common diseases
    possible_symptoms = set()
    for disease in common_diseases:
        # Filter symptoms associated with the common diseases and user's input symptoms
        disease_symptoms = set(symptom_to_diseases_df[symptom_to_diseases_df['Connected Diseases'].apply(lambda x: disease in x)]['Symptom'])
        possible_symptoms.update(disease_symptoms)

    possible_symptoms.difference_update(user_symptoms)  # Exclude already entered symptoms

    # Print the possible symptoms
    if possible_symptoms:
        print("\nPossible symptoms:")
        for i, symptom in enumerate(possible_symptoms, start=1):
            print(f"{i}. {symptom}")

        # Ask the user to select a symptom by its corresponding number
        selected_number = input("Please enter the number corresponding to the symptom you want to choose: ")
        try:
            selected_index = int(selected_number)
            if 1 <= selected_index <= len(possible_symptoms):
                user_input = list(possible_symptoms)[selected_index - 1]
                if user_input not in user_symptoms:
                    user_symptoms.append(user_input)  # Append the user's input to the list of symptoms
                else:
                    print(f"You have already selected the symptom: {user_input}. Please choose another symptom.")
            else:
                print("Invalid input. Please enter a valid number.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")
    else:
        print("No additional symptoms found. Please enter more symptoms or verify your inputs.")
# Out:
# Please enter a symptom: back
# Symptoms matching 'back':
# 1. Back stiffness or tightness
# 2. Back weakness
# 3. Back mass or lump
# 4. Back cramps or spasms
# 5. Low back weakness
# 6. Low back pain
# 7. Back pain
# Enter the number corresponding to the symptom you have: 7
# You selected: Back pain
#
# Possible symptoms:
# 1. Difficulty speaking
# 2. Back mass or lump
# 3. Involuntary urination
# 4. Skin on leg or foot looks infected
# 5. Neck pain
# 6. Headache
# 7. Stiffness all over
# 8. Elbow pain
# 9. Muscle weakness
# 10. Hip pain
# 11. Fatigue
# 12. Hurts to breath
# 13. Back stiffness or tightness
# 14. Lower body pain
# 15. Abnormal involuntary movements
# 16. Excessive growth
# 17. Muscle pain
# 18. Dizziness
# 19. Shortness of breath
# 20. Emotional symptoms
# 21. Delusions or hallucinations
# 22. Sharp chest pain
# 23. Diminished hearing
# 24. Elbow weakness
# 25. Retention of urine
# 26. Back cramps or spasms
# 27. Lower abdominal pain
# 28. Weakness
# 29. Ache all over
# 30. Joint pain
# 31. Acne or pimples
# 32. Facial pain
# 33. Blood in urine
# 34. Dry or flaky scalp
# 35. Foot or toe pain
# 36. Hand or finger weakness
# 37. Feeling hot and cold
# 38. Leg weakness
# 39. Sharp abdominal pain
# 40. Foot or toe lump or mass
# 41. Low back pain
# 42. Symptoms of bladder
# 43. Double vision
# 44. Bones are painful
# 45. Skin dryness, peeling, scaliness, or roughness
# 46. Disturbance of memory
# 47. Ankle pain
# 48. Groin pain
# 49. Focal weakness
# 50. Frequent urination
# 51. Difficulty in swallowing
# 52. Knee pain
# 53. Wrist weakness
# 54. Side pain
# 55. Sleepiness
# 56. Nausea
# 57. Vomiting
# 58. Skin rash
# 59. Low back weakness
# 60. Itching of skin
# 61. Depressive or psychotic symptoms
# 62. Problems with movement
# 63. Arm pain
# 64. Skin lesion
# 65. Suprapubic pain
# 66. Rib pain
# 67. Leg pain
# 68. Shoulder pain
# 69. Hand or finger pain
# 70. Painful urination
# 71. Leg cramps or spasms
# 72. Abnormal appearing skin
# 73. Pelvic pain
# 74. Paresthesia
# 75. Loss of sensation
# Please enter the number corresponding to the symptom you want to choose: 55
# Please enter a symptom: Sleepiness
# Symptoms matching 'sleepiness':
# 1. Sleepiness
# Enter the number corresponding to the symptom you have: 1
# You have already selected the symptom: Sleepiness. Please choose another symptom.
# Please enter a symptom: Hand or finger pain
# Symptoms matching 'hand or finger pain':
# 1. Hand or finger pain
# Enter the number corresponding to the symptom you have: 1
# You selected: Hand or finger pain
# No diseases found associated with all the symptoms entered. Please enter more symptoms.
# Please enter a symptom:  Leg cramps or spasms
# Symptoms matching 'leg cramps or spasms':
# 1. Leg cramps or spasms
# Enter the number corresponding to the symptom you have: 1
# You selected: Leg cramps or spasms
# No diseases found associated with all the symptoms entered. Please enter more symptoms.
# Please enter a symptom:  Difficulty speaking
# Symptoms matching 'difficulty speaking':
# 1. Difficulty speaking
# Enter the number corresponding to the symptom you have: 1
# You selected: Difficulty speaking
# No diseases found associated with all the symptoms entered. Please enter more symptoms.
# Please enter a symptom: Facial pain
# Symptoms matching 'facial pain':
# 1. Facial pain
# Enter the number corresponding to the symptom you have: 1
# You selected: Facial pain
# No diseases found associated with all the symptoms entered. Please enter more symptoms.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3d23b53dd530> in <cell line: 4>()
#       4 while True:
#       5     # Ask the user for a symptom
# ----> 6     user_input = input("Please enter a symptom: ").strip().lower()
#       7
#       8     # Find matching symptoms in the dataset
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Initialize a list to store user's input symptoms
user_symptoms = []

while True:
    # Ask the user for a symptom
    user_input = input("Please enter a symptom: ").strip().lower()

    # Find matching symptoms in the dataset
    matching_symptoms = [symptom for symptom in symptom_to_diseases_df['Symptom'] if user_input in symptom.lower()]

    if not matching_symptoms:
        print(f"No symptoms matching '{user_input}' found. Please try again.")
        continue

    # Display matching symptoms for user to choose from
    print(f"Symptoms matching '{user_input}':")
    for idx, symptom in enumerate(matching_symptoms, 1):
        print(f"{idx}. {symptom}")

    # Ask the user which symptom they have
    selected_index = input("Enter the number corresponding to the symptom you have: ")

    # Validate user selection
    try:
        selected_index = int(selected_index)
        if 1 <= selected_index <= len(matching_symptoms):
            chosen_symptom = matching_symptoms[selected_index - 1]
            if chosen_symptom not in user_symptoms:
                user_symptoms.append(chosen_symptom)
                print(f"You selected: {chosen_symptom}")
            else:
                print(f"You have already selected the symptom: {chosen_symptom}. Please choose another symptom.")
                continue
        else:
            print("Invalid selection. Please enter a number corresponding to the symptom.")
            continue
    except ValueError:
        print("Invalid selection. Please enter a number corresponding to the symptom.")
        continue

    # Find diseases associated with all user's input symptoms
    all_symptoms_diseases = [set(symptom_to_diseases_df.loc[symptom_to_diseases_df['Symptom'] == symptom]['Connected Diseases'].explode()) for symptom in user_symptoms]
    common_diseases = set.intersection(*all_symptoms_diseases)

    if len(common_diseases) == 1:
        # If only one disease is found, display it and exit
        print("Only one disease found associated with all symptoms entered:")
        print("- " + common_diseases.pop())
        break

    # If no diseases are associated with all the symptoms entered, prompt the user to enter more symptoms
    if not common_diseases:
        print("No diseases found associated with all the symptoms entered. Please enter more symptoms.")
        continue

    # Show possible symptoms associated with the common diseases
    possible_symptoms = set()
    for disease in common_diseases:
        # Filter symptoms associated with the common diseases
        disease_symptoms = set(symptom_to_diseases_df[symptom_to_diseases_df['Connected Diseases'].apply(lambda x: disease in x)]['Symptom'])
        possible_symptoms.update(disease_symptoms)

    # Keep only those symptoms that are connected to the user's chosen symptoms
    possible_symptoms = possible_symptoms.intersection(*[
        set(symptom_to_diseases_df.loc[symptom_to_diseases_df['Symptom'] == symptom]['Connected Diseases'].explode()) for symptom in user_symptoms
    ])

    possible_symptoms.difference_update(user_symptoms)  # Exclude already entered symptoms

    # Print the possible symptoms
    if possible_symptoms:
        print("\nPossible symptoms:")
        for i, symptom in enumerate(possible_symptoms, start=1):
            print(f"{i}. {symptom}")

        # Ask the user to select a symptom by its corresponding number
        selected_number = input("Please enter the number corresponding to the symptom you want to choose: ")
        try:
            selected_index = int(selected_number)
            if 1 <= selected_index <= len(possible_symptoms):
                user_input = list(possible_symptoms)[selected_index - 1]
                if user_input not in user_symptoms:
                    user_symptoms.append(user_input)  # Append the user's input to the list of symptoms
                else:
                    print(f"You have already selected the symptom: {user_input}. Please choose another symptom.")
            else:
                print("Invalid input. Please enter a valid number.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")
    else:
        print("No additional symptoms found. Please enter more symptoms or verify your inputs.")
# Out:
# Please enter a symptom: head
# Symptoms matching 'head':
# 1. Frontal headache
# 2. Headache
# Enter the number corresponding to the symptom you have: 1
# You selected: Frontal headache
# Only one disease found associated with all symptoms entered:
# - Carbon monoxide poisoning

# %%
import pandas as pd
import pickle
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the data from the pickled file
file_path = '/content/drive/My Drive/synthetic_dataset/goal_set.p'
with open(file_path, 'rb') as file:
    consultation_data = pickle.load(file)

# Lists to hold symptoms and diseases
symptoms = []
diseases = []

# Extract symptoms and diseases from each consultation in the 'train' data
for item in consultation_data['train']:
    # Extract disease tag
    disease_tag = item['disease_tag']

    # Extract symptoms
    explicit_symptoms = list(item['goal']['explicit_inform_slots'].keys())
    implicit_symptoms = list(item['goal']['implicit_inform_slots'].keys())
    all_symptoms = explicit_symptoms + implicit_symptoms

    # Append the extracted symptoms and disease to the respective lists
    symptoms.extend(all_symptoms)
    diseases.extend([disease_tag] * len(all_symptoms))

# Create a DataFrame from the lists of symptoms and diseases
df = pd.DataFrame({
    'Disease Tag': diseases,
    'Symptom': symptoms
})

# Ask the user for a symptom
symptom_input = input("Enter a symptom: ").strip().lower()

# Find the symptom in the DataFrame
matching_symptoms = df[df['Symptom'].str.lower().str.contains(symptom_input)]

if matching_symptoms.empty:
    print(f"No matching diseases found for the symptom '{symptom_input}'.")
else:
    # Extract and display the matching diseases
    print(f"Matching diseases for the symptom '{symptom_input}':")
    for disease in matching_symptoms['Disease Tag'].unique():
        print("- " + disease)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter a symptom: Frontal headache
# Matching diseases for the symptom 'frontal headache':
# - Carbon monoxide poisoning
